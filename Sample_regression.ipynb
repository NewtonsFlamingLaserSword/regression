# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed()
points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

plt.scatter(X, y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss="mse", optimizer = adam)
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 447us/step - loss: 0.1032
# Epoch 2/50
# 500/500 [==============================] - 0s 58us/step - loss: 0.0953
# Epoch 3/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0862
# Epoch 4/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0887
# Epoch 5/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.0932
# Epoch 6/50
# 500/500 [==============================] - 0s 53us/step - loss: 0.0921
# Epoch 7/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.0869
# Epoch 8/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.0860
# Epoch 9/50
# 500/500 [==============================] - 0s 68us/step - loss: 0.0869
# Epoch 10/50
# 500/500 [==============================] - 0s 57us/step - loss: 0.0942
# Epoch 11/50
# 500/500 [==============================] - 0s 57us/step - loss: 0.1031
# Epoch 12/50
# 500/500 [==============================] - 0s 65us/step - loss: 0.0950
# Epoch 13/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.0869
# Epoch 14/50
# 500/500 [==============================] - 0s 57us/step - loss: 0.0875
# Epoch 15/50
# 500/500 [==============================] - 0s 53us/step - loss: 0.0864
# Epoch 16/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.0867
# Epoch 17/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.0861
# Epoch 18/50
# 500/500 [==============================] - 0s 53us/step - loss: 0.0882
# Epoch 19/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0830
# Epoch 20/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.0874
# Epoch 21/50
# 500/500 [==============================] - 0s 58us/step - loss: 0.0909
# Epoch 22/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0883
# Epoch 23/50
# 500/500 [==============================] - 0s 60us/step - loss: 0.0846
# Epoch 24/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.0834
# Epoch 25/50
# 500/500 [==============================] - 0s 63us/step - loss: 0.0821
# Epoch 26/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.0824
# Epoch 27/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.0913
# Epoch 28/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.0864
# Epoch 29/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.0871
# Epoch 30/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.0889
# Epoch 31/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.0830
# Epoch 32/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.0827
# Epoch 33/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.0811
# Epoch 34/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.0823
# Epoch 35/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0862
# Epoch 36/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0832
# Epoch 37/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.0836
# Epoch 38/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.0856
# Epoch 39/50
# 500/500 [==============================] - 0s 54us/step - loss: 0.0872
# Epoch 40/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.0840
# Epoch 41/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.0861
# Epoch 42/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.0922
# Epoch 43/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.0864
# Epoch 44/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.0869
# Epoch 45/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.0808
# Epoch 46/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.0831
# Epoch 47/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.0875
# Epoch 48/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.0907
# Epoch 49/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.0877
# Epoch 50/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.0819

# %%
predictions = model.predict(X)
plt.scatter(X,y)
plt.plot(X, predictions, 'ro')
plt.show()
